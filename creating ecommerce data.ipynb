# %%
from faker import Faker
fake = Faker()

# %%
import pandas as pd
customer_code = []
for _ in range(1000):
    fakecode = fake.postcode()
    cust_code = 'CUST' + fakecode
    customer_code.append(cust_code)
    
df = pd.Series(customer_code, name='customer_id')

# %%
product_code = []
for _ in range(30):
    fakecode2 = fake.postcode()
    prod = 'PROD' + fakecode2
    product_code.append(prod)
product_id = pd.Series(product_code, name='product_id')

ecommerce = pd.concat([df, product_id], axis=1)

# %%
#channels = ['Social', 'Paid_Search', 'Email']
#ecommerce['channel_name'] = pd.Series(channels)

# %%
# ecommerce['channel_id'] = ecommerce['channel_name'].apply(lambda ch: 'CHNL_01' if ch == 'Social' else 'CHNL_02' if ch == 'Paid_Search' else 'CHNL_03' if ch == 'Email' else ch)

# %%
order_code = []
for _ in range(1000):
    fakecode = fake.postcode()
    ord_code = 'ORDR' + fakecode
    order_code.append(ord_code)
    
ecommerce['order_id'] = pd.Series(order_code, name='order_id')

# %%
order_item_code = []
for _ in range(1000):
    fakecode = fake.postcode()
    ord_itm_code = ['ORDR00' + fakecode + '-0' + str(i) for i in range(1, 1001)]
    for x in ord_itm_code:
            order_item_code.append(x)
ecommerce['order_item_id'] = pd.Series(order_item_code, name='order_item_id')

# %%
campaign_code = []
for _ in range(1000):
    fakecode = fake.postcode()
    cmp_code = 'CMP' + fakecode
    campaign_code.append(cmp_code)
    
ecommerce['campaign_id'] = pd.Series(campaign_code, name='campaign_id')

# %%
customer_name = []
for _ in range(1000):
    fakename = fake.name()
    customer_name.append(fakename)
   
ecommerce['customer_name'] = pd.Series(customer_name, name='customer_name')

# %%
customer_name = []
for _ in range(1000):
    fakename = fake.name()
    customer_name.append(fakename)
   
ecommerce['customer_name'] = pd.Series(customer_name, name='customer_name')

# %%
date_code = []
for _ in range(1000):
    fakedate = fake.date_between(start_date='-2y', end_date='today')
    date_code.append(fakedate)

ecommerce['date_id'] = pd.Series(date_code, name='date_id')

# %%
products = [
    "FreePrints 4x6 Photo Print",
    "FreePrints Square Photo Print",
    "FreePrints Glossy Photo Print",
    "FreePrints Matte Photo Print",
    "FreePrints 8x10 Photo Print",
    "FreePrints Hardcover Photobook",
    "FreePrints Softcover Photobook",
    "FreePrints Layflat Photobook",
    "FreePrints Mini Photobook",
    "FreePrints Wall Calendar",
    "Personalized Holiday Greeting Card",
    "Custom Wedding Invitation Card",
    "Birth Announcement Card",
    "Thank You Card with Photo",
    "Foil-Pressed Greeting Card",
    "Personalized Business Card",
    "Personalized Photo Mug",
    "Custom Name Necklace",
    "Personalized Photo Blanket",
    "Engraved Wooden Keepsake Box",
    "Personalized Cutting Board",
    "Custom Photo Pillow",
    "Custom Printed T-Shirt",
    "Personalized Hoodie",
    "Custom Coffee Mug",
    "Personalized Phone Case",
    "Custom Tote Bag",
    "Personalized Children’s Storybook",
    "Custom Name Puzzle Book",
    "Personalized Birthday Storybook"
]

product_dim = pd.DataFrame({
    'product_id': product_id,
    'product_name': products[:30]
})

# %%
ecommerce = ecommerce.merge(product_dim, on='product_id', how='left')

# %%
ecommerce.groupby('product_id')['product_name'].nunique().max()
# Out:
# np.int64(1)

# %%
unique_id = ecommerce['product_id'].unique()
unique_product = ecommerce['product_name'].unique()

product_dict = dict(zip(unique_id, unique_product))
product_dict
# Out:
# {'PROD74548': 'FreePrints 4x6 Photo Print',
#  'PROD89866': 'FreePrints Square Photo Print',
#  'PROD51050': 'FreePrints Glossy Photo Print',
#  'PROD97478': 'FreePrints Matte Photo Print',
#  'PROD05471': 'FreePrints 8x10 Photo Print',
#  'PROD87268': 'FreePrints Hardcover Photobook',
#  'PROD21734': 'FreePrints Softcover Photobook',
#  'PROD33593': 'FreePrints Layflat Photobook',
#  'PROD99402': 'FreePrints Mini Photobook',
#  'PROD25923': 'FreePrints Wall Calendar',
#  'PROD28339': 'Personalized Holiday Greeting Card',
#  'PROD51813': 'Custom Wedding Invitation Card',
#  'PROD69973': 'Birth Announcement Card',
#  'PROD25827': 'Thank You Card with Photo',
#  'PROD17934': 'Foil-Pressed Greeting Card',
#  'PROD96197': 'Personalized Business Card',
#  'PROD86460': 'Personalized Photo Mug',
#  'PROD94040': 'Custom Name Necklace',
#  'PROD33872': 'Personalized Photo Blanket',
#  'PROD99039': 'Engraved Wooden Keepsake Box',
#  'PROD32794': 'Personalized Cutting Board',
#  'PROD88536': 'Custom Photo Pillow',
#  'PROD21438': 'Custom Printed T-Shirt',
#  'PROD11602': 'Personalized Hoodie',
#  'PROD83214': 'Custom Coffee Mug',
#  'PROD79327': 'Personalized Phone Case',
#  'PROD18051': 'Custom Tote Bag',
#  'PROD96708': 'Personalized Children’s Storybook',
#  'PROD77938': 'Custom Name Puzzle Book',
#  'PROD05112': 'Personalized Birthday Storybook',
#  nan: nan}

# %%
len(product_dict)
# Out:
# 31

# %%
ecommerce[['product_id', 'product_name']]
# Out:
#     product_id                   product_name
# 0    PROD74548     FreePrints 4x6 Photo Print
# 1    PROD89866  FreePrints Square Photo Print
# 2    PROD51050  FreePrints Glossy Photo Print
# 3    PROD97478   FreePrints Matte Photo Print
# 4    PROD05471    FreePrints 8x10 Photo Print
# ..         ...                            ...
# 995        NaN                            NaN
# 996        NaN                            NaN
# 997        NaN                            NaN
# 998        NaN                            NaN
# 999        NaN                            NaN
#
# [1000 rows x 2 columns]

# %%
import numpy as np
channels = ['Social', 'Paid_Search', 'Email']

ecommerce['channel_name'] = np.random.choice(channels, size=len(ecommerce))

channel_dict = {
    'Social': 'CHNL_01',
    'Paid_Search': 'CHNL_02',
    'Email': 'CHNL_03'
}

ecommerce['channel_id'] = ecommerce['channel_name'].map(channel_dict)

# %%
ecommerce
# Out:
#     customer_id product_id   order_id      order_item_id campaign_id  \
# 0     CUST02579  PROD74548  ORDR01881     ORDR0059306-01    CMP48317
# 1     CUST64561  PROD89866  ORDR70203     ORDR0059306-02    CMP60844
# 2     CUST29995  PROD51050  ORDR38776     ORDR0059306-03    CMP14440
# 3     CUST41620  PROD97478  ORDR60875     ORDR0059306-04    CMP17746
# 4     CUST76648  PROD05471  ORDR17150     ORDR0059306-05    CMP07045
# ..          ...        ...        ...                ...         ...
# 995   CUST63525        NaN  ORDR97200   ORDR0059306-0996    CMP73595
# 996   CUST64479        NaN  ORDR95420   ORDR0059306-0997    CMP71753
# 997   CUST47655        NaN  ORDR57016   ORDR0059306-0998    CMP23679
# 998   CUST12335        NaN  ORDR86542   ORDR0059306-0999    CMP21881
# 999   CUST95556        NaN  ORDR61198  ORDR0059306-01000    CMP32996
#
#         customer_name     date_id                   product_name channel_name  \
# 0    Anthony Mitchell  2025-02-27     FreePrints 4x6 Photo Print        Email
# 1       Chloe Vasquez  2024-06-11  FreePrints Square Photo Print  Paid_Search
# 2           Tina Koch  2025-10-28  FreePrints Glossy Photo Print  Paid_Search
# 3      Michelle Potts  2024-05-15   FreePrints Matte Photo Print       Social
# 4     Brenda Fletcher  2025-05-29    FreePrints 8x10 Photo Print  Paid_Search
# ..                ...         ...                            ...          ...
# 995        Julie Hall  2024-03-26                            NaN        Email
# 996  Timothy Thompson  2025-02-03                            NaN        Email
# 997      Nathan Curry  2025-05-04                            NaN        Email
# 998        Lisa Lewis  2024-06-17                            NaN       Social
# 999      Linda Nelson  2024-12-09                            NaN  Paid_Search
#
#     channel_id
# 0      CHNL_03
# 1      CHNL_02
# 2      CHNL_02
# 3      CHNL_01
# 4      CHNL_02
# ..         ...
# 995    CHNL_03
# 996    CHNL_03
# 997    CHNL_03
# 998    CHNL_01
# 999    CHNL_02
#
# [1000 rows x 10 columns]

# %%
ecommerce.columns
# Out:
# Index(['customer_id', 'product_id', 'order_id', 'order_item_id', 'campaign_id',
#        'customer_name', 'date_id', 'product_name', 'channel_name',
#        'channel_id'],
#       dtype='object')

# %%
# Generate a random floating-point number between 5 and 150, then round it to 2 decimal places
price_dict = {product: round(random.uniform(5, 150), 2) for product in products}
price_dict
# Out:
# {'FreePrints 4x6 Photo Print': 109.31,
#  'FreePrints Square Photo Print': 105.08,
#  'FreePrints Glossy Photo Print': 145.3,
#  'FreePrints Matte Photo Print': 48.99,
#  'FreePrints 8x10 Photo Print': 16.05,
#  'FreePrints Hardcover Photobook': 94.2,
#  'FreePrints Softcover Photobook': 78.86,
#  'FreePrints Layflat Photobook': 105.49,
#  'FreePrints Mini Photobook': 123.03,
#  'FreePrints Wall Calendar': 49.36,
#  'Personalized Holiday Greeting Card': 137.45,
#  'Custom Wedding Invitation Card': 98.5,
#  'Birth Announcement Card': 8.7,
#  'Thank You Card with Photo': 18.98,
#  'Foil-Pressed Greeting Card': 30.42,
#  'Personalized Business Card': 128.17,
#  'Personalized Photo Mug': 86.32,
#  'Custom Name Necklace': 25.91,
#  'Personalized Photo Blanket': 90.34,
#  'Engraved Wooden Keepsake Box': 50.78,
#  'Personalized Cutting Board': 61.35,
#  'Custom Photo Pillow': 81.34,
#  'Custom Printed T-Shirt': 107.92,
#  'Personalized Hoodie': 8.5,
#  'Custom Coffee Mug': 8.1,
#  'Personalized Phone Case': 94.36,
#  'Custom Tote Bag': 24.97,
#  'Personalized Children’s Storybook': 19.3,
#  'Custom Name Puzzle Book': 24.41,
#  'Personalized Birthday Storybook': 135.99}

# %%
ecommerce['product_name'] = np.random.choice(products, size=len(ecommerce))

ecommerce['product_cost'] = ecommerce['product_name'].map(price_dict)

# %%
ecommerce
# Out:
#     customer_id product_id   order_id      order_item_id campaign_id  \
# 0     CUST02579  PROD74548  ORDR01881     ORDR0059306-01    CMP48317
# 1     CUST64561  PROD89866  ORDR70203     ORDR0059306-02    CMP60844
# 2     CUST29995  PROD51050  ORDR38776     ORDR0059306-03    CMP14440
# 3     CUST41620  PROD97478  ORDR60875     ORDR0059306-04    CMP17746
# 4     CUST76648  PROD05471  ORDR17150     ORDR0059306-05    CMP07045
# ..          ...        ...        ...                ...         ...
# 995   CUST63525        NaN  ORDR97200   ORDR0059306-0996    CMP73595
# 996   CUST64479        NaN  ORDR95420   ORDR0059306-0997    CMP71753
# 997   CUST47655        NaN  ORDR57016   ORDR0059306-0998    CMP23679
# 998   CUST12335        NaN  ORDR86542   ORDR0059306-0999    CMP21881
# 999   CUST95556        NaN  ORDR61198  ORDR0059306-01000    CMP32996
#
#         customer_name     date_id                        product_name  \
# 0    Anthony Mitchell  2025-02-27          Personalized Cutting Board
# 1       Chloe Vasquez  2024-06-11          Personalized Photo Blanket
# 2           Tina Koch  2025-10-28  Personalized Holiday Greeting Card
# 3      Michelle Potts  2024-05-15                     Custom Tote Bag
# 4     Brenda Fletcher  2025-05-29             Custom Name Puzzle Book
# ..                ...         ...                                 ...
# 995        Julie Hall  2024-03-26          Foil-Pressed Greeting Card
# 996  Timothy Thompson  2025-02-03        FreePrints Matte Photo Print
# 997      Nathan Curry  2025-05-04            FreePrints Wall Calendar
# 998        Lisa Lewis  2024-06-17          Personalized Business Card
# 999      Linda Nelson  2024-12-09        FreePrints Matte Photo Print
#
#     channel_name channel_id  product_cost
# 0          Email    CHNL_03         61.35
# 1    Paid_Search    CHNL_02         90.34
# 2    Paid_Search    CHNL_02        137.45
# 3         Social    CHNL_01         24.97
# 4    Paid_Search    CHNL_02         24.41
# ..           ...        ...           ...
# 995        Email    CHNL_03         30.42
# 996        Email    CHNL_03         48.99
# 997        Email    CHNL_03         49.36
# 998       Social    CHNL_01        128.17
# 999  Paid_Search    CHNL_02         48.99
#
# [1000 rows x 11 columns]
